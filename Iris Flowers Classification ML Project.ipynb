# %% [markdown]
# # Iris Flowers Classification ML Project
# **By- `Suraj Honkamble`**
# ### Beginner Level Task-1

# %% [markdown]
# ### Import required libraries and packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

# %% [markdown]
# ### Load and read the dataset

# %%
df=pd.read_csv('D:\\DATA SCIENCE Internship with LGMVIP\\data\\iris.csv', header=None)
df.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %% [markdown]
# #### Add Column names

# %%
df.columns=['sepal_length','sepal_width','petal_length','petal_width','class']
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ### Column Information
# 1. sepal length in cm
# 2. sepal width in cm
# 3. petal length in cm
# 4. petal width in cm
# 5. class: a.Iris Setosa b.Iris Versicolour c. Iris Virginica

# %% [markdown]
# ### Data Understanding

# %%
df.shape
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   class         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ### Statistical Measures

# %%
df.describe().T
# Out:
#               count      mean       std  min  25%   50%  75%  max
# sepal_length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# sepal_width   150.0  3.054000  0.433594  2.0  2.8  3.00  3.3  4.4
# petal_length  150.0  3.758667  1.764420  1.0  1.6  4.35  5.1  6.9
# petal_width   150.0  1.198667  0.763161  0.1  0.3  1.30  1.8  2.5

# %% [markdown]
# 1. **Average Sepal legth for all 3 classes is 5.84cm., average sepal width is 3.05cm, average petal length is 3.75cm and average petal width is 1.19cm.**
# 2. **Maximum sepal length is 7.9cm and minimum sepal length is 4.3 cm. Maximum sepal width is 4.4cm and minimum sepal width is 0.43cm, maximum petal length and width are 6.9cm and 2.5 cm respectively. Minimum petal length and minimum petal width are 1.76cm and 0.76cm respectively.**
# 3. **Each Class has 50 rows.**

# %% [markdown]
# ### Missing value

# %%
df.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# class           0
# dtype: int64

# %% [markdown]
# **No missing values in dataset.**

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# **Since all 4 input atributes here are continous numerical type hence use Boxplot to detect any outliers, KDE, Hist to check the data distribution.**

# %% [markdown]
# ### Outliers

# %%
fig,ax=plt.subplots(2,2, figsize=(20,10))
plt.suptitle('Outliers In Each column by Class of the Flower', fontsize=18, color='blue')
sns.boxplot(y='sepal_length', x='class', data=df,  ax=ax[0,0], color='red')
sns.boxplot(y='sepal_width', x='class', data=df, ax=ax[0,1], color='orange')
sns.boxplot(y='petal_length', x='class', data=df, ax=ax[1,0], color='blue')
sns.boxplot(y='petal_width', x='class', data=df, ax=ax[1,1], color='green');

# %% [markdown]
# 1. **There are some outliers but these are not extreme outliers so we will not treat them.**
# 2. **For an Iris Satosa: Sepal length, petal length, petal width is smaller as compared to other classes. but the sepal width is little larger than any other classes.**

# %% [markdown]
# ### Data Destribution in each column

# %%
fig,ax=plt.subplots(2,2, figsize=(20,8))
plt.suptitle('Data Destribution', fontsize=18, color='blue')
sns.boxplot(x='sepal_length', data=df, color='yellow', ax=ax[0,0])
sns.boxplot(x='sepal_width', data=df, color='pink', ax=ax[0,1])
sns.boxplot(x='petal_length', data=df, color='orange', ax=ax[1,0])
sns.boxplot(x='petal_width', data=df, color='lightblue', ax=ax[1,1]);

# %%
fig,ax=plt.subplots(2,2, figsize=(20,8))
plt.suptitle('Data Destribution', fontsize=18, color='blue')
sns.histplot(x='sepal_length', data=df, color='yellow', kde=True, ax=ax[0,0])
sns.histplot(x='sepal_width', data=df, color='pink', kde=True, ax=ax[0,1])
sns.histplot(x='petal_length', data=df, color='orange', kde=True, ax=ax[1,0])
sns.histplot(x='petal_width', data=df, color='lightblue', kde=True,  ax=ax[1,1]);

# %% [markdown]
# #### All atributes data points are somewhat look normally distributed and there is no extream outliers in of the column.

# %% [markdown]
# ### Correlation between features

# %%
sns.pairplot(df, hue='class');

# %% [markdown]
# **From above all the paiplots we can see that the blue data points which belongs to class setosa are easily seperated from rest two class data points.**

# %% [markdown]
# ## Machine Learning Classification model

# %% [markdown]
# ### Check whether Number of categories are equal in size or not

# %%
df['class'].value_counts().plot(kind='barh');

# %% [markdown]
# #### Each class have equal number of rows

# %% [markdown]
# ### Replace Class data type from object to string

# %%
df['class'].replace({"Iris-setosa":0,"Iris-versicolor":1, "Iris-virginica":2}, inplace=True)
df['class'].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %% [markdown]
# ### Split data into input and target feature

# %%
X=df.iloc[:,:-1]
y=df['class']
X[:5]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
y[:5]
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: class, dtype: int64

# %% [markdown]
# ### Split input and target data into train and test set

# %% [markdown]
# #### In the test set I want equal number of rows for each class, so that algorithm can learn from equal number of data points from each class and hence define `Stratify` in  train test split

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(X,y, test_size=0.2, random_state=0,
                                               shuffle=True, stratify=y)
print("X train Shape", x_train.shape)
print("X test Shape", x_test.shape)
print("y train Shape", y_train.shape)
print("y test Shape", y_test.shape)
# Out:
# X train Shape (120, 4)
# X test Shape (30, 4)
# y train Shape (120,)
# y test Shape (30,)

# %%
y_test.value_counts()
# Out:
# 0    10
# 1    10
# 2    10
# Name: class, dtype: int64

# %% [markdown]
# ### Feature Scalling
# - Here all the column value are in centimeter ie all the values are in same scale so no need of tranformation.

# %% [markdown]
# ## Select best fit algorithm to predict class of Iris flower
# - Our target variable has 3 class hence use multiclass classification model to predict the target.

# %% [markdown]
# ## KNN classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

knn=KNeighborsClassifier(n_neighbors=5)
knn=knn.fit(x_train,y_train)
y_test_pred=knn.predict(x_test)

# %% [markdown]
# ### Evaluate the model

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, plot_roc_curve

print("Confusion Matrix:\n",confusion_matrix(y_test, y_test_pred))
print(f"Out of total {y_test.shape[0]} test values {sum(y_test!=y_test_pred)} are missclassified")
# Out:
# Confusion Matrix:
#  [[10  0  0]
#  [ 0 10  0]
#  [ 0  0 10]]
# Out of total 30 test values 0 are missclassified

# %%
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00        10
#            2       1.00      1.00      1.00        10
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
acc=(accuracy_score(y_test, y_test_pred)*100).round(4)
results=pd.DataFrame({"Algorithm":["KNN Classifier"], "Accuracy":[acc]})
results
# Out:
#         Algorithm  Accuracy
# 0  KNN Classifier     100.0

# %% [markdown]
# ### We got 100% test accuracy so need to go for any complex models. We are using KNN algorithm to predic if any future data points comes.

# %% [markdown]
# ### Test For New Data point

# %%
sample=pd.DataFrame({"sepal_length":[4.4,3.5,5.4,6.1],
                     "sepal_width":[3.5,2.4,4.0,3.5],
                     "petal_length":[2,5,4,6],
                     "petal_width":[2,1.5,1.4,1.8]})
sample
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           4.4          3.5             2          2.0
# 1           3.5          2.4             5          1.5
# 2           5.4          4.0             4          1.4
# 3           6.1          3.5             6          1.8

# %% [markdown]
# #### Predict for these data points

# %%
predict_class=knn.predict(sample)
for iris_class in predict_class:
    if iris_class==0:
        print("Flower is Satosa")
    elif iris_class==1:
        print("Flower is Versicolor")
    else:
        print("Flower is Virginica")
# Out:
# Flower is Satosa
# Flower is Versicolor
# Flower is Versicolor
# Flower is Virginica
